# %% [markdown]
# 快速双击M键位可以将代码转化为Markdown格式
#
#
# Python基础知识:
# 有类型:
#     基础类型:int byte short long    double float(保留的小数点后的有效数字长度不一样)  bool char
#     复合类型:list tuple dict set range str
#
#
# python的基础函数:
# ① type(x)  查看x的类型
# ② len(x)   查看x的长度 length
# ③ input()  输入 , 输入的数据一定是str类型 ,自学:类型转化
# ④ print()  输出

# %%
x = 10
y = 20
print(x * y)
h = '小灰灰'
print(h*2)
m = type(h)
print(m)
print(type(x))
k = 123.1111
print(type(k))

print(len("xiaohuihui"))
print(2131567890085465789083546789034456789084354*435679809567896546789678/465787983456798)

# h = input("请输入一个整数:")
# print(h,type(h))    
# 计算机x+y 
x = input("请输入一个整数:")
y = input("请输入另一个整数:")
print(x + y)

# 大模型幻象 466W亿
# Out:
# 200
# 小灰灰小灰灰
# <class 'str'>
# <class 'int'>
# <class 'float'>
# 10
# 1.9937849953563998e+51
# 100200

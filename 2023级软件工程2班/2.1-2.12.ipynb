# %%
import heapq as hq
from collections import deque

s1 = "hello world"
countX = s1.count('l')
print(countX)


s2 = s1.find('l')
print(s2)


s3 = s1.rfind('l') # 找到最后一个'l'元素
print(s3)


s4 = s1.index('l')
print(s4)

s5 = s1.replace(s1[s4], 'x')
print(s5,s1)



s6 = s1.isdigit()
print(s6)

print("123.456".isdigit()) # digit 数字 == interger 整数


# strip() # 去除左右两侧的空格 strip('.')



st = ['a','b','c','d'] # 列表同时也是一个栈stack
'''

增删改查
len(st)
st.append('e')
st.pop()
st.pop(0)
st.insert(0,'x')
st.remove('b')
st.reverse()
st.sort()
st.sort(reverse=True)
st.sort(key=len)
st.sort(key=str.lower)
st.extend(st2)

'''


'''
keb(dq) == 0  not dq

pop()默认从末端删除
'''


xhh = deque()
xhh.append('a') # default from end
xhh.appendleft('b')
xhh.appendleft('k')

print(xhh)


h1 = hq.heappush([10,6,7,1],1)
print(h1,hq)
# Out:
# 3
# 2
# 9
# 2
# hexxo worxd hello world
# False
# False
# deque(['k', 'b', 'a'])
# None <module 'heapq' from '/root/.pyenv/versions/3.11.1/lib/python3.11/heapq.py'>
